# %%
# !pip install pandas
# !pip install scikit-learn
# !pip install matplotlib
# !pip install seaborn
# Out:
# Requirement already satisfied: pandas in c:\users\kesdr\miniconda3\envs\adsfinal\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\kesdr\miniconda3\envs\adsfinal\lib\site-packages (from pandas) (2.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\kesdr\miniconda3\envs\adsfinal\lib\site-packages (from pandas) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kesdr\miniconda3\envs\adsfinal\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\kesdr\miniconda3\envs\adsfinal\lib\site-packages (from pandas) (2025.1)
# Requirement already satisfied: six>=1.5 in c:\users\kesdr\miniconda3\envs\adsfinal\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: scikit-learn in c:\users\kesdr\miniconda3\envs\adsfinal\lib\site-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\kesdr\miniconda3\envs\adsfinal\lib\site-packages (from scikit-learn) (2.2.2)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\kesdr\miniconda3\envs\adsfinal\lib\site-packages (from scikit-learn) (1.15.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\kesdr\miniconda3\envs\adsfinal\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\kesdr\miniconda3\envs\adsfinal\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: matplotlib in c:\users\kesdr\miniconda3\envs\adsfinal\lib\site-packages (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\kesdr\miniconda3\envs\adsfinal\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\kesdr\miniconda3\envs\adsfinal\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\kesdr\miniconda3\envs\adsfinal\lib\site-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\kesdr\miniconda3\envs\adsfinal\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in c:\users\kesdr\miniconda3\envs\adsfinal\lib\site-packages (from matplotlib) (2.2.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\kesdr\miniconda3\envs\adsfinal\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\kesdr\miniconda3\envs\adsfinal\lib\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\kesdr\miniconda3\envs\adsfinal\lib\site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\kesdr\miniconda3\envs\adsfinal\lib\site-packages (from matplotlib) (2.9.0)
# Requirement already satisfied: six>=1.5 in c:\users\kesdr\miniconda3\envs\adsfinal\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: seaborn in c:\users\kesdr\miniconda3\envs\adsfinal\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\kesdr\miniconda3\envs\adsfinal\lib\site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: pandas>=1.2 in c:\users\kesdr\miniconda3\envs\adsfinal\lib\site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\kesdr\miniconda3\envs\adsfinal\lib\site-packages (from seaborn) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\kesdr\miniconda3\envs\adsfinal\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\kesdr\miniconda3\envs\adsfinal\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\kesdr\miniconda3\envs\adsfinal\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\kesdr\miniconda3\envs\adsfinal\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\kesdr\miniconda3\envs\adsfinal\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\kesdr\miniconda3\envs\adsfinal\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\kesdr\miniconda3\envs\adsfinal\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\kesdr\miniconda3\envs\adsfinal\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kesdr\miniconda3\envs\adsfinal\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\kesdr\miniconda3\envs\adsfinal\lib\site-packages (from pandas>=1.2->seaborn) (2025.1)
# Requirement already satisfied: six>=1.5 in c:\users\kesdr\miniconda3\envs\adsfinal\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)

# %%
import pandas as pd
from scipy import stats
from sklearn.cluster import KMeans
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
bls = pd.read_csv("C:/Users/kesdr/Downloads/bls_data.csv")
print(bls.head())
# Out:
#               series_id  year period  value     footnotes
# 0  LAUMT063108000000003  2024    M11    5.4  Preliminary.
# 1  LAUMT063108000000003  2024    M10    5.6           NaN
# 2  LAUMT063108000000003  2024    M09    5.5           NaN
# 3  LAUMT063108000000003  2024    M08    6.2           NaN
# 4  LAUMT063108000000003  2024    M07    6.0           NaN

# %%
print('Number of instances = %d' % (bls.shape[0]))
print('Number of attributes = %d' % (bls.shape[1]))
# Out:
# Number of instances = 524
# Number of attributes = 5

# %%
print('Number of missing values:')
for col in bls.columns:
    print(f'{col}: {bls[col].isna().sum()}')
# Out:
# Number of missing values:
# series_id: 0
# year: 0
# period: 0
# value: 0
# footnotes: 520

# %%
blsdrop = bls.drop(columns=['footnotes'])
blsdrop
# Out:
#                 series_id  year period      value
# 0    LAUMT063108000000003  2024    M11        5.4
# 1    LAUMT063108000000003  2024    M10        5.6
# 2    LAUMT063108000000003  2024    M09        5.5
# 3    LAUMT063108000000003  2024    M08        6.2
# 4    LAUMT063108000000003  2024    M07        6.0
# ..                    ...   ...    ...        ...
# 519  LAUMT063108000000006  2014    M05  6523953.0
# 520  LAUMT063108000000006  2014    M04  6505721.0
# 521  LAUMT063108000000006  2014    M03  6544226.0
# 522  LAUMT063108000000006  2014    M02  6527749.0
# 523  LAUMT063108000000006  2014    M01  6483077.0
#
# [524 rows x 4 columns]

# %%
print('Number of missing values:')
for col in blsdrop.columns:
    print(f'{col}: {blsdrop[col].isna().sum()}')
# Out:
# Number of missing values:
# series_id: 0
# year: 0
# period: 0
# value: 0

# %%
print(f"Duplicate rows: {blsdrop.duplicated().sum()}")
# Out:
# Duplicate rows: 0

# %%
#EDA

# %%
blsdrop['year'] = blsdrop['year'].astype(int)
blsdrop['value'] = blsdrop['value'].astype(float)
blsdrop['month'] = blsdrop['period'].str.extract('(\d+)').astype(int)
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\d'
# <>:3: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\kesdr\AppData\Local\Temp\ipykernel_33276\2370633528.py:3: SyntaxWarning: invalid escape sequence '\d'
#   blsdrop['month'] = blsdrop['period'].str.extract('(\d+)').astype(int)

# %%
#to look at the month
blsdrop['date'] = pd.to_datetime(blsdrop['year'].astype(str) + '-' + blsdrop['month'].astype(str) + '-01')
print(blsdrop.head())
# Out:
#               series_id  year period  value  month       date
# 0  LAUMT063108000000003  2024    M11    5.4     11 2024-11-01
# 1  LAUMT063108000000003  2024    M10    5.6     10 2024-10-01
# 2  LAUMT063108000000003  2024    M09    5.5      9 2024-09-01
# 3  LAUMT063108000000003  2024    M08    6.2      8 2024-08-01
# 4  LAUMT063108000000003  2024    M07    6.0      7 2024-07-01

# %%
#descriptive stats for value 
print(blsdrop['value'].describe())
# Out:
# count    5.240000e+02
# mean     3.312406e+06
# std      3.127834e+06
# min      3.700000e+00
# 25%      1.856250e+05
# 50%      3.123469e+06
# 75%      6.493090e+06
# max      6.925383e+06
# Name: value, dtype: float64

# %%
#determining unique series id values
print("Unique series_id values:", blsdrop['series_id'].unique())
# Out:
# Unique series_id values: ['LAUMT063108000000003' 'LAUMT063108000000004' 'LAUMT063108000000005'
#  'LAUMT063108000000006']

# %%
plt.figure(figsize=(10, 6))
sns.histplot(blsdrop['value'], bins=30, kde=True)
plt.title('Distribution of Labor Statistic Values')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
annual_mean = blsdrop.groupby(['year', 'series_id'])['value'].mean().reset_index()

plt.figure(figsize=(10, 6))
sns.lineplot(data=annual_mean, x='year', y='value', hue='series_id', marker="o")
plt.title('Annual Mean Value per Series ID')
plt.xlabel('Year')
plt.ylabel('Mean Value')
plt.legend(title='Series ID')
plt.show()

# %%
annual_values = blsdrop.groupby(['year', 'series_id'])['value'].mean().reset_index()

plt.figure(figsize=(12, 8))
sns.barplot(data=annual_values, x='year', y='value', hue='series_id')
plt.title('Annual Average Labor Statistic Values by Series ID')
plt.xlabel('Year')
plt.ylabel('Average Value')
plt.xticks(rotation=45)
plt.legend(title='Series ID')
plt.show()

# %%
unique_series = blsdrop['series_id'].unique()

for sid in unique_series:
    subset = blsdrop[blsdrop['series_id'] == sid].sort_values('date')
    plt.figure(figsize=(10, 5))
    plt.plot(subset['date'], subset['value'], marker='o', linestyle='-')
    plt.title(f"Time Series for Series ID: {sid}")
    plt.xlabel("Date")
    plt.ylabel("Value")
    plt.grid(True)
    plt.show()

# %%
df = blsdrop.sort_values('date')

g = sns.FacetGrid(df, col="series_id", col_wrap=2, height=4, sharey=False)
g.map(sns.lineplot, "date", "value", marker="o")
g.set_axis_labels("Date", "Value")
g.fig.suptitle("Monthly Labor Statistics by Series ID", y=1.05)
plt.show()
